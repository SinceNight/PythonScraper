# %%
import requests
n=0

with open("一锤定音",mode="r",encoding="utf-8") as f:
    for line in f:
        line = line.strip() # 先去掉空格，空白，换行符
        if line.startswith("#"): #以#号开头的内容不要
            continue
        print(line)

        # 下载视频片段

        resp3 =requests.get(line)
        f = open ("video/"+f"{n}.ts",mode="wb")
        f.write(resp3.content)
        n+=1
# Out:
# https://m3api.awenhao.com/phls/MzY5ZDdSWk9LbzRnM24rdThiQ2xxTmVWdVVTaTdvRmZjS2ZVNzNObEhid3MzKzZ6NFhBeDR0WTlERklCOXI1NFcxYzNOQlF3TXFEb2Nnc0kzTDZSZUZweXQyclhIbzRTUVBLMkxVZ3c2WkhPaDZaRVpwb01CSmRPNUwzZGpGMFJ5d29ZR0pIRndVVTZ0ZUU=
# https://m3api.awenhao.com/phls/ODBiOHkwMVhzMGRZV0FOeWRtRFozVktyMkJuVlpCM25kbFZhWmlSR08vR1JLU0p3N1AwMjRqUGdJV1VnaC9HLzRZNTJNQ0dLSmZtcU1JU1A4VkVlL1VxUC95NWJMMnNBZTdhRGh3ZVQ1QWJuZ0tMVFVTeFY4OUJrKzRUVTRFQjBUSStqOFE1cFhkTzdnUkE=
# https://m3api.awenhao.com/phls/ZjA3ZnJnRnNwYXhsUWorWS94M3pTam13RXJLeE5TckVhSjhBZTcrcExzMWdHRnVXNVdkQm9GTjZXaFJkU0F3WXNxY2FxOGM4c3dSL2NaM1BsZkJFT2hzQ2lXNW9UbUVuMk1pTnprMi8zMzNrd2JhdFA5RzVHTjg0ZVBKMkFyL2U4eGNuaDE4NFdqS1p2Rms=
# https://m3api.awenhao.com/phls/ODA1MVM5TUhlYWY0cEdKNVZBdnl0ODdLa0tsdEVWMzlNWjBqR2FaWXloeEJ3TDQ1NG1waUJqaCtudUNpaitTTnRjTGd3ekd2Qnp5SmtxY0pnMkFDWHV1K2krYkhUa1JDZ2hKaVlxRjdQZ0J5UG41WTRrbk55V2cySWd4d3ZTVGI2d1FJWWpmdXNoVzFzeGM=
# https://m3api.awenhao.com/phls/YmUzMGZCTDhRY3NCU3pvNWRTaGVtS3llQzh3OHllRnpzbXhvWkw2dkRJbHFiZzQyczdNakk0K0tlcDNLVXVZa215RkpsQ0NlYlcrN0JTdzhVUm9EVzRKckh1VmRWWG00ckNBazd5YVpVWW96QTgzS2hSUjZQckp0dHdlTUdsOFJEVnowS0VFRHRWU2dObHM=
# https://m3api.awenhao.com/phls/NjE0MklmT2IxeVJmZGZVdzlBK2Z5MXVFd1h3dG9sV0VjL2xldnhITklJbVp4Zkdsem9ZdTljWDZrNXlrWFhCL1ppTXN3Q1o4M0lnd0JPaDhjZlhPU2RXN3BxZk94eVVncFV0NDZ1eFpKUzVtdVpBNGZKUmlJMGkrNFpDN2U5WGdRZ044ZDJPMHdaWXRQRlk=
# https://m3api.awenhao.com/phls/MmZkN3l2NmVWKzlJNW9yOU10VDh1ekkxWXkwaVVoVkI5MmFOb3BNcGlzVi8vOGU3NmhnbHFZTm1KSmV1ZlRzVHBNWUREdzlLMHQzMVY2L1lDaURnZTdXdHlEblpncFR2bUYya2tIT0htSDA0YWlhVFZIUyt2TkFYQmVOd2dpSFBrdC90Y2taMnFvZG1iRTQ=
# https://m3api.awenhao.com/phls/YzI2M2RiWThoV01zZ25IWWoyUTRCZk50azBnV2lKWC9xRmdkd1NTaWt4MXVzNEoreU5HN2dFcVliTFhnbmNvRk96WVB2dUJRUWt4Rmxwek1yWGhBKzZjN05DQ01CU3F5VnUwaXdoQ0hpaUFkc2NoWE9sVHFudXpoQzJ4QVhDZ1Z2SHpIcHFTY0dGcndGMWc=
# https://m3api.awenhao.com/phls/ZTcwZFQ1Ri9kQldQYkhBeWhCek02RW9BU2pUSzVYVWtobW5iM0hxOThMWHFUa0pGM2E2azZON1F1cXJkRXdwaVRseEh5SVJoR1ZFWGJrVEt2NDQvYnM0T2JIL2JwQTY3NmszdG1DVkZ6T2tCL2N6eE1XOVVJUTlYaXVhQnNEcmJMQ1JVYUgxWmYwVjdUMFk=
# https://m3api.awenhao.com/phls/YjhlNWUxRncwSjZKUWQ5TW4rSXc3aXFMQnlQa0lFcllJdnZFTjh1Q2lhQzN2QkZKUnFKMVR5Tk55MFNvcnRhVmRlQWJwL0h4MDdPcXovUWhXRklmbjd4dkZQUUVhcklGNUZJWmtLTXRqRXVueGxYeW9TclFPZ0YrZHlGQlpjdjZ5NmNNT1FsZkV0WmY1SW8=
# https://m3api.awenhao.com/phls/YzYyYk9KVVFJTXdZUzJrTC9QMnlLSDRrVTBlUm1mdHI1d0p0cXpsVjdHNm0wUitSeVZTTlQrTm1xK01hODAyTGc5TWZxd2tRbTdlMHpkYWdia3V3NU9KZSttS1ExWllZRWJqZElDMU9BUENSdUxPc0JiVlZWdUFCNUU4djZNKzFaUXJPQzNpSzZkczFBRzQ=
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\zella\Desktop\interest\PythonScraper\code\6_M3U8_video\解析一锤定音.ipynb Cell 1' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/zella/Desktop/interest/PythonScraper/code/6_M3U8_video/%E8%A7%A3%E6%9E%90%E4%B8%80%E9%94%A4%E5%AE%9A%E9%9F%B3.ipynb#ch0000001?line=8'>9</a> print(line)
#      <a href='vscode-notebook-cell:/c%3A/Users/zella/Desktop/interest/PythonScraper/code/6_M3U8_video/%E8%A7%A3%E6%9E%90%E4%B8%80%E9%94%A4%E5%AE%9A%E9%9F%B3.ipynb#ch0000001?line=10'>11</a> # 下载视频片段
# ---> <a href='vscode-notebook-cell:/c%3A/Users/zella/Desktop/interest/PythonScraper/code/6_M3U8_video/%E8%A7%A3%E6%9E%90%E4%B8%80%E9%94%A4%E5%AE%9A%E9%9F%B3.ipynb#ch0000001?line=12'>13</a> resp3 =requests.get(line)
#      <a href='vscode-notebook-cell:/c%3A/Users/zella/Desktop/interest/PythonScraper/code/6_M3U8_video/%E8%A7%A3%E6%9E%90%E4%B8%80%E9%94%A4%E5%AE%9A%E9%9F%B3.ipynb#ch0000001?line=13'>14</a> f = open ("video/"+f"{n}.ts",mode="wb")
#      <a href='vscode-notebook-cell:/c%3A/Users/zella/Desktop/interest/PythonScraper/code/6_M3U8_video/%E8%A7%A3%E6%9E%90%E4%B8%80%E9%94%A4%E5%AE%9A%E9%9F%B3.ipynb#ch0000001?line=14'>15</a> f.write(resp3.content)
#
# File D:\python\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      <a href='file:///d%3A/python/lib/site-packages/requests/api.py?line=63'>64</a> def get(url, params=None, **kwargs):
#      <a href='file:///d%3A/python/lib/site-packages/requests/api.py?line=64'>65</a>     r"""Sends a GET request.
#      <a href='file:///d%3A/python/lib/site-packages/requests/api.py?line=65'>66</a>
#      <a href='file:///d%3A/python/lib/site-packages/requests/api.py?line=66'>67</a>     :param url: URL for the new :class:`Request` object.
#    (...)
#      <a href='file:///d%3A/python/lib/site-packages/requests/api.py?line=71'>72</a>     :rtype: requests.Response
#      <a href='file:///d%3A/python/lib/site-packages/requests/api.py?line=72'>73</a>     """
# ---> <a href='file:///d%3A/python/lib/site-packages/requests/api.py?line=74'>75</a>     return request('get', url, params=params, **kwargs)
#
# File D:\python\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      <a href='file:///d%3A/python/lib/site-packages/requests/api.py?line=56'>57</a> # By using the 'with' statement we are sure the session is closed, thus we
#      <a href='file:///d%3A/python/lib/site-packages/requests/api.py?line=57'>58</a> # avoid leaving sockets open which can trigger a ResourceWarning in some
#      <a href='file:///d%3A/python/lib/site-packages/requests/api.py?line=58'>59</a> # cases, and look like a memory leak in others.
#      <a href='file:///d%3A/python/lib/site-packages/requests/api.py?line=59'>60</a> with sessions.Session() as session:
# ---> <a href='file:///d%3A/python/lib/site-packages/requests/api.py?line=60'>61</a>     return session.request(method=method, url=url, **kwargs)
#
# File D:\python\lib\site-packages\requests\sessions.py:542, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=536'>537</a> send_kwargs = {
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=537'>538</a>     'timeout': timeout,
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=538'>539</a>     'allow_redirects': allow_redirects,
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=539'>540</a> }
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=540'>541</a> send_kwargs.update(settings)
# --> <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=541'>542</a> resp = self.send(prep, **send_kwargs)
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=543'>544</a> return resp
#
# File D:\python\lib\site-packages\requests\sessions.py:677, in Session.send(self, request, **kwargs)
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=673'>674</a> if allow_redirects:
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=674'>675</a>     # Redirect resolving generator.
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=675'>676</a>     gen = self.resolve_redirects(r, request, **kwargs)
# --> <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=676'>677</a>     history = [resp for resp in gen]
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=677'>678</a> else:
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=678'>679</a>     history = []
#
# File D:\python\lib\site-packages\requests\sessions.py:677, in <listcomp>(.0)
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=673'>674</a> if allow_redirects:
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=674'>675</a>     # Redirect resolving generator.
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=675'>676</a>     gen = self.resolve_redirects(r, request, **kwargs)
# --> <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=676'>677</a>     history = [resp for resp in gen]
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=677'>678</a> else:
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=678'>679</a>     history = []
#
# File D:\python\lib\site-packages\requests\sessions.py:237, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=233'>234</a>     yield req
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=234'>235</a> else:
# --> <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=236'>237</a>     resp = self.send(
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=237'>238</a>         req,
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=238'>239</a>         stream=stream,
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=239'>240</a>         timeout=timeout,
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=240'>241</a>         verify=verify,
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=241'>242</a>         cert=cert,
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=242'>243</a>         proxies=proxies,
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=243'>244</a>         allow_redirects=False,
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=244'>245</a>         **adapter_kwargs
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=245'>246</a>     )
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=247'>248</a>     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=249'>250</a>     # extract redirect url, if any, for the next loop
#
# File D:\python\lib\site-packages\requests\sessions.py:697, in Session.send(self, request, **kwargs)
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=693'>694</a>         pass
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=695'>696</a> if not stream:
# --> <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=696'>697</a>     r.content
#     <a href='file:///d%3A/python/lib/site-packages/requests/sessions.py?line=698'>699</a> return r
#
# File D:\python\lib\site-packages\requests\models.py:836, in Response.content(self)
#     <a href='file:///d%3A/python/lib/site-packages/requests/models.py?line=833'>834</a>         self._content = None
#     <a href='file:///d%3A/python/lib/site-packages/requests/models.py?line=834'>835</a>     else:
# --> <a href='file:///d%3A/python/lib/site-packages/requests/models.py?line=835'>836</a>         self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     <a href='file:///d%3A/python/lib/site-packages/requests/models.py?line=837'>838</a> self._content_consumed = True
#     <a href='file:///d%3A/python/lib/site-packages/requests/models.py?line=838'>839</a> # don't need to release the connection; that's been handled by urllib3
#     <a href='file:///d%3A/python/lib/site-packages/requests/models.py?line=839'>840</a> # since we exhausted the data.
#
# File D:\python\lib\site-packages\requests\models.py:758, in Response.iter_content.<locals>.generate()
#     <a href='file:///d%3A/python/lib/site-packages/requests/models.py?line=755'>756</a> if hasattr(self.raw, 'stream'):
#     <a href='file:///d%3A/python/lib/site-packages/requests/models.py?line=756'>757</a>     try:
# --> <a href='file:///d%3A/python/lib/site-packages/requests/models.py?line=757'>758</a>         for chunk in self.raw.stream(chunk_size, decode_content=True):
#     <a href='file:///d%3A/python/lib/site-packages/requests/models.py?line=758'>759</a>             yield chunk
#     <a href='file:///d%3A/python/lib/site-packages/requests/models.py?line=759'>760</a>     except ProtocolError as e:
#
# File D:\python\lib\site-packages\urllib3\response.py:576, in HTTPResponse.stream(self, amt, decode_content)
#     <a href='file:///d%3A/python/lib/site-packages/urllib3/response.py?line=573'>574</a> else:
#     <a href='file:///d%3A/python/lib/site-packages/urllib3/response.py?line=574'>575</a>     while not is_fp_closed(self._fp):
# --> <a href='file:///d%3A/python/lib/site-packages/urllib3/response.py?line=575'>576</a>         data = self.read(amt=amt, decode_content=decode_content)
#     <a href='file:///d%3A/python/lib/site-packages/urllib3/response.py?line=577'>578</a>         if data:
#     <a href='file:///d%3A/python/lib/site-packages/urllib3/response.py?line=578'>579</a>             yield data
#
# File D:\python\lib\site-packages\urllib3\response.py:519, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     <a href='file:///d%3A/python/lib/site-packages/urllib3/response.py?line=516'>517</a> else:
#     <a href='file:///d%3A/python/lib/site-packages/urllib3/response.py?line=517'>518</a>     cache_content = False
# --> <a href='file:///d%3A/python/lib/site-packages/urllib3/response.py?line=518'>519</a>     data = self._fp.read(amt) if not fp_closed else b""
#     <a href='file:///d%3A/python/lib/site-packages/urllib3/response.py?line=519'>520</a>     if (
#     <a href='file:///d%3A/python/lib/site-packages/urllib3/response.py?line=520'>521</a>         amt != 0 and not data
#     <a href='file:///d%3A/python/lib/site-packages/urllib3/response.py?line=521'>522</a>     ):  # Platform-specific: Buggy versions of Python.
#    (...)
#     <a href='file:///d%3A/python/lib/site-packages/urllib3/response.py?line=527'>528</a>         # not properly close the connection in all cases. There is
#     <a href='file:///d%3A/python/lib/site-packages/urllib3/response.py?line=528'>529</a>         # no harm in redundantly calling close.
#     <a href='file:///d%3A/python/lib/site-packages/urllib3/response.py?line=529'>530</a>         self._fp.close()
#
# File D:\python\lib\http\client.py:458, in HTTPResponse.read(self, amt)
#     <a href='file:///d%3A/python/lib/http/client.py?line=454'>455</a> if amt is not None:
#     <a href='file:///d%3A/python/lib/http/client.py?line=455'>456</a>     # Amount is given, implement using readinto
#     <a href='file:///d%3A/python/lib/http/client.py?line=456'>457</a>     b = bytearray(amt)
# --> <a href='file:///d%3A/python/lib/http/client.py?line=457'>458</a>     n = self.readinto(b)
#     <a href='file:///d%3A/python/lib/http/client.py?line=458'>459</a>     return memoryview(b)[:n].tobytes()
#     <a href='file:///d%3A/python/lib/http/client.py?line=459'>460</a> else:
#     <a href='file:///d%3A/python/lib/http/client.py?line=460'>461</a>     # Amount is not given (unbounded read) so we must check self.length
#     <a href='file:///d%3A/python/lib/http/client.py?line=461'>462</a>     # and self.chunked
#
# File D:\python\lib\http\client.py:502, in HTTPResponse.readinto(self, b)
#     <a href='file:///d%3A/python/lib/http/client.py?line=496'>497</a>         b = memoryview(b)[0:self.length]
#     <a href='file:///d%3A/python/lib/http/client.py?line=498'>499</a> # we do not use _safe_read() here because this may be a .will_close
#     <a href='file:///d%3A/python/lib/http/client.py?line=499'>500</a> # connection, and the user is reading more bytes than will be provided
#     <a href='file:///d%3A/python/lib/http/client.py?line=500'>501</a> # (for example, reading in 1k chunks)
# --> <a href='file:///d%3A/python/lib/http/client.py?line=501'>502</a> n = self.fp.readinto(b)
#     <a href='file:///d%3A/python/lib/http/client.py?line=502'>503</a> if not n and b:
#     <a href='file:///d%3A/python/lib/http/client.py?line=503'>504</a>     # Ideally, we would raise IncompleteRead if the content-length
#     <a href='file:///d%3A/python/lib/http/client.py?line=504'>505</a>     # wasn't satisfied, but it might break compatibility.
#     <a href='file:///d%3A/python/lib/http/client.py?line=505'>506</a>     self._close_conn()
#
# File D:\python\lib\socket.py:704, in SocketIO.readinto(self, b)
#     <a href='file:///d%3A/python/lib/socket.py?line=701'>702</a> while True:
#     <a href='file:///d%3A/python/lib/socket.py?line=702'>703</a>     try:
# --> <a href='file:///d%3A/python/lib/socket.py?line=703'>704</a>         return self._sock.recv_into(b)
#     <a href='file:///d%3A/python/lib/socket.py?line=704'>705</a>     except timeout:
#     <a href='file:///d%3A/python/lib/socket.py?line=705'>706</a>         self._timeout_occurred = True
#
# File D:\python\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    <a href='file:///d%3A/python/lib/ssl.py?line=1236'>1237</a>     if flags != 0:
#    <a href='file:///d%3A/python/lib/ssl.py?line=1237'>1238</a>         raise ValueError(
#    <a href='file:///d%3A/python/lib/ssl.py?line=1238'>1239</a>           "non-zero flags not allowed in calls to recv_into() on %s" %
#    <a href='file:///d%3A/python/lib/ssl.py?line=1239'>1240</a>           self.__class__)
# -> <a href='file:///d%3A/python/lib/ssl.py?line=1240'>1241</a>     return self.read(nbytes, buffer)
#    <a href='file:///d%3A/python/lib/ssl.py?line=1241'>1242</a> else:
#    <a href='file:///d%3A/python/lib/ssl.py?line=1242'>1243</a>     return super().recv_into(buffer, nbytes, flags)
#
# File D:\python\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    <a href='file:///d%3A/python/lib/ssl.py?line=1096'>1097</a> try:
#    <a href='file:///d%3A/python/lib/ssl.py?line=1097'>1098</a>     if buffer is not None:
# -> <a href='file:///d%3A/python/lib/ssl.py?line=1098'>1099</a>         return self._sslobj.read(len, buffer)
#    <a href='file:///d%3A/python/lib/ssl.py?line=1099'>1100</a>     else:
#    <a href='file:///d%3A/python/lib/ssl.py?line=1100'>1101</a>         return self._sslobj.read(len)
#
# KeyboardInterrupt:
